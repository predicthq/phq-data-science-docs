# %% [markdown]
# The purpose of this notebook is to demonstrate how you can get relevant forecast-ready features for your locations at scale. To do this, we will use the [Beam API](https://docs.predicthq.com/api/beam).
#
# Make sure you have a predefined set of locations with corresponding demand data ready before running this notebook. The output is a list of important features for each of your locations.

# %% [markdown]
# # Steps
#
# * [Setup](#setup)
# * [Step 1. Prepare Data](#step-1-prepare-data)
# * [Step 2. Beam: Upload Data](#step-2-beam-upload-data)
# * [Step 3. Beam: Get Feature Importance](#step-3-beam-get-feature-importance)

# %% [markdown]
# # Setup

# %% [markdown]
# Complete the following steps before proceeding:
#
# 1. Install `requirements.txt`
# 2. Replace `ACCESS_TOKEN` with a valid token (for help creating an access token, see [the API Quickstart](https://docs.predicthq.com/getting-started/api-quickstart))

# %%
# install requirements
# %pip install --user -r requirements.txt

# %%
import pandas as pd
import json
import os
from predicthq import Client
import phq_api_utils as pau

# %%
DATA_DIR = "data"
OUTPUT_DIR = "output"

ACCESS_TOKEN = "REPLACE_WITH_ACCESS_TOKEN"

# %%
phq = Client(access_token=ACCESS_TOKEN)

# %% [markdown]
# # Step 1. Prepare Data

# %% [markdown]
# **New Analyses**
#
# To create new Analyses in Beam, the following are required:
#
# 1. Demand data
#
#     a. One csv file with columns for `location`, `date` and `demand` (see [here](https://docs.predicthq.com/api/beam/upload-demand-data#request-body) for more details)
#
# 2. Config file with the following information per `location`:
#
#     a. `lat`/`lon`: the coordinates of the location
#
#     b. `analysis_name`: a user-created free-form string to reference the Analysis in Beam
#
#     c. `industry`: the industry relevant to your locations (`accommodation`, `parking`, `restaurants` or `retail`), default is `other`
#
#
# See the example config below for how this should look.

# %%
# read and inspect demand file
demand_df = pd.read_csv(os.path.join(DATA_DIR, "demand.csv"))
demand_df.head()
# Out:
#   location        date       demand
# 0  store_0  2017-01-02  5552.019186
# 1  store_0  2017-01-03  8299.941863
# 2  store_0  2017-01-04  8556.730072
# 3  store_0  2017-01-05  8595.100423
# 4  store_0  2017-01-06  8198.941337

# %%
# load config file
with open(os.path.join(DATA_DIR, "config.json"), "r") as f:
    config = json.load(f)

config = pau.supplement_config(config=config, demand_df=demand_df)

# %%
config
# Out:
# {'store_0': {'lat': 40.74559205863674,
#   'lon': -73.9945205785237,
#   'analysis_name': 'store_0_daily_analysis',
#   'industry': 'restaurants',
#   'start': '2017-01-02',
#   'end': '2019-12-31'},
#  'store_1': {'lat': 33.971191942428334,
#   'lon': -118.16436160102515,
#   'analysis_name': 'store_1_daily_analysis',
#   'industry': 'restaurants',
#   'start': '2017-01-02',
#   'end': '2018-11-30'},
#  'store_2': {'lat': 40.751582853596915,
#   'lon': -73.98155897848956,
#   'analysis_name': 'store_2_monday_weekly_analysis',
#   'industry': 'restaurants',
#   'start': '2017-01-09',
#   'end': '2019-12-23'},
#  'store_3': {'lat': 40.74559205863674,
#   'lon': -73.9945205785237,
#   'analysis_name': 'store_3_monday_weekly_analysis',
#   'industry': 'restaurants',
#   'start': '2017-01-09',
#   'end': '2019-12-23'}}

# %% [markdown]
# **Existing Analyses**
#
# If you have existing Analyses in Beam, the following are required:
#
# 1. Config file
#
#     a. `analysis_id`: the ID associated with a Beam Analysis
#
#     b. `analysis_name`: the user-created free-form string to reference the Analysis in Beam
#
# If your Analyses were created before the launch of Feature Importance, a refresh is also required.
#
# Otherwise, skip to [Step 3. Beam: Get Feature Importance](#step-3-beam-get-feature-importance).

# %%
# example config for existing Analyses
# config = {
#     "store_0": {
#         "analysis_id": "abc123",
#         "analysis_name": "store_0_analysis",
#     },
#     "store_1": {
#         "analysis_id": "def456",
#         "analysis_name": "store_1_analysis",
#     },
#     "store_2": {
#         "analysis_id": "ghi789",
#         "analysis_name": "store_2_analysis",
#     },
# }

# %%
# refresh Analyses
# for location, info in config.items():
#     print(f"Refreshing analysis for {location}...")
#     refresh_status = pau.refresh_analysis(analysis_id=info["analysis_id"], access_token=ACCESS_TOKEN)
#     info["refresh_status"] = refresh_status

# %% [markdown]
# # Step 2. Beam: Upload Data

# %% [markdown]
# **New Analyses**
#
# This step involves using the [Beam API](https://docs.predicthq.com/api/beam) to:
#
# 1. Create an `analysis_id` for each location
# 2. Upload demand for each Analysis
# 3. Check Analysis `readiness_status` and make sure all are `ready` before proceeding
#
# For more info on the Beam API and other functionality such as updating and deleting Analyses, see the [PredictHQ Docs](https://docs.predicthq.com/api/beam).

# %%
# create Analysis id and upload demand
for location, info in config.items():
    print(f"Uploading demand for {location}...")

    try:
        analysis_id = pau.create_analysis_id(location=info, access_token=ACCESS_TOKEN)

        location_demand_df = demand_df[demand_df["location"] == location].drop(
            columns=["location"]
        )
        location_demand_json = location_demand_df.to_json(orient="records")

        upload_status = pau.upload_demand(
            demand_json=location_demand_json,
            analysis_id=analysis_id,
            access_token=ACCESS_TOKEN,
        )

        info.update(
            {
                "analysis_id": analysis_id,
                "upload_status": upload_status,
            }
        )

    except Exception as e:
        print(f"--- an error occurred: {e}")
# Out:
# Uploading demand for store_0...
# --- the request has been accepted for processing.
# Uploading demand for store_1...
# --- the request has been accepted for processing.
# Uploading demand for store_2...
# --- the request has been accepted for processing.
# Uploading demand for store_3...
# --- the request has been accepted for processing.

# %% [markdown]
# The more Analyses you process, the longer it takes. Analyses need to be `ready` before proceeding to the next steps. Refresh as needed to get the latest status.

# %%
# check readiness status is `ready`
for location, info in config.items():
    print(f"Readiness status for {location}...")

    analysis_details = pau.get_analysis_details(
        analysis_id=info["analysis_id"], access_token=ACCESS_TOKEN
    )

    readiness_status = analysis_details.get("readiness_status", None)
    info["readiness_status"] = readiness_status
    print(f"--- {readiness_status}")

# save config file
with open(os.path.join(OUTPUT_DIR, "config_updated.json"), "w") as f:
    json.dump(config, f, indent=4)
# Out:
# Readiness status for store_0...
# --- ready
# Readiness status for store_1...
# --- ready
# Readiness status for store_2...
# --- ready
# Readiness status for store_3...
# --- ready

# %% [markdown]
# # Step 3. Beam: Get Feature Importance

# %% [markdown]
# Feature Importance results can be retrieved for all Analyses via their `analysis_id`.

# %% [markdown]
# **All Analyses**

# %%
# get feature importance
for location, info in config.items():
    print(f"Getting feature importance for {location}...")

    try:
        feature_importance = pau.get_feature_importance(
            analysis_id=info["analysis_id"], access_token=ACCESS_TOKEN
        )
        important_features = [
            item
            for feature in feature_importance["feature_importance"]
            if feature["important"]
            for item in feature["features"]
        ]
        info["important_features"] = important_features
        info["feature_importance"] = feature_importance["feature_importance"]

        print("--- feature importance retrieved")

    except Exception as e:
        print(f"--- an error occurred: {e}")

# save config file
with open(os.path.join(OUTPUT_DIR, "config_updated_with_features.json"), "w") as f:
    json.dump(config, f, indent=4)
# Out:
# Getting feature importance for store_0...
# --- feature importance retrieved
# Getting feature importance for store_1...
# --- feature importance retrieved
# Getting feature importance for store_2...
# --- feature importance retrieved
# Getting feature importance for store_3...
# --- feature importance retrieved

# %%
config
# Out:
# {'store_0': {'lat': 40.74559205863674,
#   'lon': -73.9945205785237,
#   'analysis_name': 'store_0_daily_analysis',
#   'industry': 'restaurants',
#   'start': '2017-01-02',
#   'end': '2019-12-31',
#   'analysis_id': 'itHSB5-WICk',
#   'upload_status': 202,
#   'readiness_status': 'ready',
#   'important_features': ['phq_attendance_expos_hospitality',
#    'phq_impact_public_holidays_hospitality',
#    'phq_impact_observances_hospitality',
#    'phq_impact_academic_holiday',
#    'phq_impact_academic_exam',
#    'phq_attendance_sports_hospitality',
#    'phq_impact_severe_weather_cold_wave_storm_retail',
#    'phq_impact_severe_weather_cold_wave_retail',
#    'phq_attendance_community_hospitality',
#    'phq_attendance_conferences_hospitality'],
#   'feature_importance': [{'feature_group': 'expos',
#     'features': ['phq_attendance_expos_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'public-holidays',
#     'features': ['phq_impact_public_holidays_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'observances',
#     'features': ['phq_impact_observances_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'academic',
#     'features': ['phq_impact_academic_holiday', 'phq_impact_academic_exam'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'sports',
#     'features': ['phq_attendance_sports_hospitality'],
#     'p_value': 0.0007,
#     'important': True},
#    {'feature_group': 'severe-weather',
#     'features': ['phq_impact_severe_weather_cold_wave_storm_retail',
#      'phq_impact_severe_weather_cold_wave_retail'],
#     'p_value': 0.0106,
#     'important': True},
#    {'feature_group': 'community',
#     'features': ['phq_attendance_community_hospitality'],
#     'p_value': 0.0213,
#     'important': True},
#    {'feature_group': 'conferences',
#     'features': ['phq_attendance_conferences_hospitality'],
#     'p_value': 0.0213,
#     'important': True},
#    {'feature_group': 'performing-arts',
#     'features': ['phq_attendance_performing_arts_hospitality'],
#     'p_value': 0.7076,
#     'important': False},
#    {'feature_group': 'concerts',
#     'features': ['phq_attendance_concerts_hospitality'],
#     'p_value': 0.8192,
#     'important': False},
#    {'feature_group': 'school-holidays',
#     'features': ['phq_impact_school_holidays'],
#     'p_value': 0.8192,
#     'important': False},
#    {'feature_group': 'festivals',
#     'features': ['phq_attendance_festivals_hospitality'],
#     'p_value': 0.9506,
#     'important': False}]},
#  'store_1': {'lat': 33.971191942428334,
#   'lon': -118.16436160102515,
#   'analysis_name': 'store_1_daily_analysis',
#   'industry': 'restaurants',
#   'start': '2017-01-02',
#   'end': '2018-11-30',
#   'analysis_id': 'XCwohExDJH4',
#   'upload_status': 202,
#   'readiness_status': 'ready',
#   'important_features': ['phq_attendance_school_holidays',
#    'phq_attendance_festivals_hospitality',
#    'phq_attendance_sports_hospitality',
#    'phq_impact_public_holidays_hospitality',
#    'phq_impact_observances_hospitality',
#    'phq_impact_severe_weather_cold_wave_storm_retail',
#    'phq_impact_severe_weather_tornado_retail',
#    'phq_impact_severe_weather_heat_wave_retail'],
#   'feature_importance': [{'feature_group': 'school-holidays',
#     'features': ['phq_attendance_school_holidays'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'festivals',
#     'features': ['phq_attendance_festivals_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'sports',
#     'features': ['phq_attendance_sports_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'public-holidays',
#     'features': ['phq_impact_public_holidays_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'observances',
#     'features': ['phq_impact_observances_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'severe-weather',
#     'features': ['phq_impact_severe_weather_cold_wave_storm_retail',
#      'phq_impact_severe_weather_tornado_retail',
#      'phq_impact_severe_weather_heat_wave_retail'],
#     'p_value': 0.0164,
#     'important': True}]},
#  'store_2': {'lat': 40.751582853596915,
#   'lon': -73.98155897848956,
#   'analysis_name': 'store_2_monday_weekly_analysis',
#   'industry': 'restaurants',
#   'start': '2017-01-09',
#   'end': '2019-12-23',
#   'analysis_id': 'yFtsOK53__M',
#   'upload_status': 202,
#   'readiness_status': 'ready',
#   'important_features': ['phq_attendance_performing_arts_hospitality',
#    'phq_attendance_expos_hospitality',
#    'phq_impact_public_holidays_hospitality',
#    'phq_impact_school_holidays',
#    'phq_impact_observances_hospitality',
#    'phq_attendance_concerts_hospitality',
#    'phq_impact_severe_weather_thunderstorm_retail',
#    'phq_impact_severe_weather_cold_wave_retail',
#    'phq_impact_severe_weather_cold_wave_storm_retail',
#    'phq_impact_severe_weather_flood_retail',
#    'phq_impact_academic_holiday',
#    'phq_impact_academic_exam',
#    'phq_attendance_sports_hospitality',
#    'phq_attendance_conferences_hospitality'],
#   'feature_importance': [{'feature_group': 'performing-arts',
#     'features': ['phq_attendance_performing_arts_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'expos',
#     'features': ['phq_attendance_expos_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'public-holidays',
#     'features': ['phq_impact_public_holidays_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'school-holidays',
#     'features': ['phq_impact_school_holidays'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'observances',
#     'features': ['phq_impact_observances_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'concerts',
#     'features': ['phq_attendance_concerts_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'severe-weather',
#     'features': ['phq_impact_severe_weather_thunderstorm_retail',
#      'phq_impact_severe_weather_cold_wave_retail',
#      'phq_impact_severe_weather_cold_wave_storm_retail',
#      'phq_impact_severe_weather_flood_retail'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'academic',
#     'features': ['phq_impact_academic_holiday', 'phq_impact_academic_exam'],
#     'p_value': 0.0013,
#     'important': True},
#    {'feature_group': 'sports',
#     'features': ['phq_attendance_sports_hospitality'],
#     'p_value': 0.008,
#     'important': True},
#    {'feature_group': 'conferences',
#     'features': ['phq_attendance_conferences_hospitality'],
#     'p_value': 0.008,
#     'important': True},
#    {'feature_group': 'community',
#     'features': ['phq_attendance_community_hospitality'],
#     'p_value': 0.9992,
#     'important': False},
#    {'feature_group': 'festivals',
#     'features': ['phq_attendance_festivals_hospitality'],
#     'p_value': 0.9999,
#     'important': False}]},
#  'store_3': {'lat': 40.74559205863674,
#   'lon': -73.9945205785237,
#   'analysis_name': 'store_3_monday_weekly_analysis',
#   'industry': 'restaurants',
#   'start': '2017-01-09',
#   'end': '2019-12-23',
#   'analysis_id': 'rUpVMrAcqCQ',
#   'upload_status': 202,
#   'readiness_status': 'ready',
#   'important_features': ['phq_attendance_performing_arts_hospitality',
#    'phq_attendance_conferences_hospitality',
#    'phq_impact_public_holidays_hospitality',
#    'phq_impact_observances_hospitality',
#    'phq_attendance_sports_hospitality',
#    'phq_impact_academic_holiday',
#    'phq_impact_academic_exam',
#    'phq_attendance_community_hospitality',
#    'phq_attendance_festivals_hospitality',
#    'phq_attendance_expos_hospitality',
#    'phq_impact_severe_weather_flood_retail',
#    'phq_impact_severe_weather_cold_wave_retail',
#    'phq_impact_severe_weather_cold_wave_storm_retail',
#    'phq_impact_severe_weather_thunderstorm_retail'],
#   'feature_importance': [{'feature_group': 'performing-arts',
#     'features': ['phq_attendance_performing_arts_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'conferences',
#     'features': ['phq_attendance_conferences_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'public-holidays',
#     'features': ['phq_impact_public_holidays_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'observances',
#     'features': ['phq_impact_observances_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'sports',
#     'features': ['phq_attendance_sports_hospitality'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'academic',
#     'features': ['phq_impact_academic_holiday', 'phq_impact_academic_exam'],
#     'p_value': 0.0,
#     'important': True},
#    {'feature_group': 'community',
#     'features': ['phq_attendance_community_hospitality'],
#     'p_value': 0.0001,
#     'important': True},
#    {'feature_group': 'festivals',
#     'features': ['phq_attendance_festivals_hospitality'],
#     'p_value': 0.0001,
#     'important': True},
#    {'feature_group': 'expos',
#     'features': ['phq_attendance_expos_hospitality'],
#     'p_value': 0.0001,
#     'important': True},
#    {'feature_group': 'severe-weather',
#     'features': ['phq_impact_severe_weather_flood_retail',
#      'phq_impact_severe_weather_cold_wave_retail',
#      'phq_impact_severe_weather_cold_wave_storm_retail',
#      'phq_impact_severe_weather_thunderstorm_retail'],
#     'p_value': 0.0001,
#     'important': True},
#    {'feature_group': 'concerts',
#     'features': ['phq_attendance_concerts_hospitality'],
#     'p_value': 0.9998,
#     'important': False},
#    {'feature_group': 'school-holidays',
#     'features': ['phq_impact_school_holidays'],
#     'p_value': 0.9999,
#     'important': False}]}}
